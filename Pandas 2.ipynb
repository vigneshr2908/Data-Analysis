# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'D:\Learning & Projects\Python\Pandas\Boris\employees.csv')
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
df['Start Date'] = pd.to_datetime(df['Start Date'])

# %%
df['Last Login Time'] = pd.to_datetime(df['Last Login Time'])

# %%
df['Senior Management'] = df['Senior Management'].astype('bool')

# %%
df['Gender'] = df['Gender'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 49.0+ KB

# %%
# Collating all the codes above

df = pd.read_csv(r'D:\Learning & Projects\Python\Pandas\Boris\employees.csv', parse_dates=['Start Date', 'Last Login Time'])
# df['Start Date'] = pd.to_datetime(df['Start Date'])
# df['Last Login Time'] = pd.to_datetime(df['Last Login Time'])
df['Senior Management'] = df['Senior Management'].astype('bool')
df['Gender'] = df['Gender'].astype('category')
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2022-08-13 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2022-08-13 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2022-08-13 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
# Filtering out Male Employees

df[df['Gender'] == 'Male'].head()
# Out:
#   First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas   Male 1993-08-06 2022-08-12 12:42:00   97308    6.945
# 1     Thomas   Male 1996-03-31 2022-08-12 06:53:00   61933    4.170
# 3      Jerry   Male 2005-03-04 2022-08-12 13:00:00  138705    9.340
# 4      Larry   Male 1998-01-24 2022-08-12 16:47:00  101004    1.389
# 5     Dennis   Male 1987-04-18 2022-08-12 01:35:00  115163   10.125
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 3               True          Finance
# 4               True  Client Services
# 5              False            Legal

# %%
marketing_team = df['Team']=="Marketing"
non_marketing_team = df['Team'] != 'Marketing'

# %%
df[marketing_team]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-08-12 12:42:00   97308    6.945
# 21     Matthew    Male 1995-09-05 2022-08-12 02:12:00  100612   13.645
# 26       Craig    Male 2000-02-27 2022-08-12 07:45:00   37598    7.757
# 43     Marilyn  Female 1980-12-07 2022-08-12 03:16:00   73524    5.207
# 62         NaN  Female 2007-06-12 2022-08-12 17:25:00   58112   19.414
# ..         ...     ...        ...                 ...     ...      ...
# 942       Lori  Female 2015-11-20 2022-08-12 13:15:00   75498    6.537
# 947        NaN    Male 2012-07-30 2022-08-12 15:07:00  107351    5.329
# 986      Donna  Female 1982-11-26 2022-08-12 07:04:00   82871   17.999
# 991       Rose  Female 2002-08-25 2022-08-12 05:12:00  134505   11.051
# 994     George    Male 2013-06-21 2022-08-12 17:47:00   98874    4.479
#
#      Senior Management       Team
# 0                 True  Marketing
# 21               False  Marketing
# ...

# %%
df[df['Salary'] > 100000]

df[df['Bonus %'] < 5]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2022-08-12 06:53:00   61933    4.170
# 4        Larry    Male 1998-01-24 2022-08-12 16:47:00  101004    1.389
# 15     Lillian  Female 2016-06-05 2022-08-12 06:09:00   59414    1.256
# 19       Donna  Female 2010-07-22 2022-08-12 03:48:00   81014    1.894
# 20        Lois     NaN 1995-04-22 2022-08-12 19:18:00   64714    4.934
# ..         ...     ...        ...                 ...     ...      ...
# 976     Denise  Female 1992-10-19 2022-08-12 05:42:00  137954    4.195
# 985    Stephen     NaN 1983-07-10 2022-08-12 20:10:00   85668    1.909
# 989     Justin     NaN 1991-02-10 2022-08-12 16:58:00   38344    3.794
# 994     George    Male 2013-06-21 2022-08-12 17:47:00   98874    4.479
# 997    Russell    Male 2013-05-20 2022-08-12 12:39:00   96914    1.421
#
#      Senior Management             Team
# 1                 True              NaN
# ...

# %%
df[df['Start Date'] <= '1981-01-20']
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 10      Louise  Female 1980-08-12 2022-08-12 09:01:00   63241   15.132
# 12     Brandon    Male 1980-12-01 2022-08-12 01:08:00  112807   17.492
# 43     Marilyn  Female 1980-12-07 2022-08-12 03:16:00   73524    5.207
# 45       Roger    Male 1980-04-17 2022-08-12 11:32:00   88010   13.886
# 49       Chris     NaN 1980-01-24 2022-08-12 12:13:00  113590    3.055
# 82      Steven    Male 1980-03-30 2022-08-12 21:20:00   35095    8.379
# 154    Rebecca  Female 1980-11-15 2022-08-12 04:13:00   85730    5.359
# 213     Evelyn  Female 1980-05-24 2022-08-12 23:10:00   81673   15.364
# 272       Fred    Male 1980-02-20 2022-08-12 02:25:00   74129   18.225
# 303       Joan     NaN 1980-07-25 2022-08-12 12:22:00   38712    3.657
# 384       Jack    Male 1980-12-24 2022-08-12 22:58:00  106995   15.723
# 423    Deborah  Female 1980-11-25 2022-08-12 04:33:00   46953   17.436
# ...

# %% [markdown]
# ### Filtering with multiple conditions

# %%
df = pd.read_csv(r'D:\Learning & Projects\Python\Pandas\Boris\employees.csv', parse_dates=['Start Date', 'Last Login Time'])
# df['Start Date'] = pd.to_datetime(df['Start Date'])
# df['Last Login Time'] = pd.to_datetime(df['Last Login Time'])
df['Senior Management'] = df['Senior Management'].astype('bool')
df['Gender'] = df['Gender'].astype('category')
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2022-08-12 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2022-08-12 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2022-08-12 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
mask1 = df['Gender'] == 'Male'
mask2 = df['Team'] == 'Marketing'

df[mask1 & mask2]
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2022-08-12 12:42:00   97308    6.945
# 21     Matthew   Male 1995-09-05 2022-08-12 02:12:00  100612   13.645
# 26       Craig   Male 2000-02-27 2022-08-12 07:45:00   37598    7.757
# 74      Thomas   Male 1995-06-04 2022-08-12 14:24:00   62096   17.029
# 77     Charles   Male 2004-09-14 2022-08-12 20:13:00  107391    1.260
# 101      Aaron   Male 2012-02-17 2022-08-12 10:20:00   61602   11.849
# 104       John   Male 1989-12-23 2022-08-12 07:01:00   80740   19.305
# 112     Willie   Male 2003-11-27 2022-08-12 06:21:00   64363    4.023
# 119       Paul   Male 2008-06-03 2022-08-12 15:05:00   41054   12.299
# 150       Sean   Male 1996-05-04 2022-08-12 20:59:00  135490   19.934
# 187      Roger   Male 2004-11-19 2022-08-12 15:55:00   51430    6.460
# 204     Willie   Male 2006-06-06 2022-08-12 09:45:00   55281    4.935
# ...

# %%
df[mask1 | mask2]
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2022-08-12 12:42:00   97308    6.945
# 1       Thomas   Male 1996-03-31 2022-08-12 06:53:00   61933    4.170
# 3        Jerry   Male 2005-03-04 2022-08-12 13:00:00  138705    9.340
# 4        Larry   Male 1998-01-24 2022-08-12 16:47:00  101004    1.389
# 5       Dennis   Male 1987-04-18 2022-08-12 01:35:00  115163   10.125
# ..         ...    ...        ...                 ...     ...      ...
# 994     George   Male 2013-06-21 2022-08-12 17:47:00   98874    4.479
# 996    Phillip   Male 1984-01-31 2022-08-12 06:30:00   42392   19.675
# 997    Russell   Male 2013-05-20 2022-08-12 12:39:00   96914    1.421
# 998      Larry   Male 2013-04-20 2022-08-12 16:45:00   60500   11.985
# 999     Albert   Male 2012-05-15 2022-08-12 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
mult_teams = df['Team'].isin(['Marketing', 'Legal', 'Product'])
df[mult_teams]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-08-13 12:42:00   97308    6.945
# 5       Dennis    Male 1987-04-18 2022-08-13 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 2022-08-13 16:20:00   65476   10.012
# 11       Julie  Female 1997-10-26 2022-08-13 15:19:00  102508   12.637
# 15     Lillian  Female 2016-06-05 2022-08-13 06:09:00   59414    1.256
# ..         ...     ...        ...                 ...     ...      ...
# 986      Donna  Female 1982-11-26 2022-08-13 07:04:00   82871   17.999
# 989     Justin     NaN 1991-02-10 2022-08-13 16:58:00   38344    3.794
# 991       Rose  Female 2002-08-25 2022-08-13 05:12:00  134505   11.051
# 994     George    Male 2013-06-21 2022-08-13 17:47:00   98874    4.479
# 997    Russell    Male 2013-05-20 2022-08-13 12:39:00   96914    1.421
#
#      Senior Management       Team
# 0                 True  Marketing
# 5                False      Legal
# ...

# %%
df['Team'].isnull()
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Team, Length: 1000, dtype: bool

# %%
sal_60_70 = df['Salary'].between(60000, 70000)  # both arguments are inclusive
df[df['Start Date'].between('1991-10-25', '1991-11-24')]
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 339    Michael   Male 1991-11-22 2022-08-13 12:57:00   98753   16.443
# 603       Carl    NaN 1991-10-26 2022-08-13 08:11:00  100888   12.490
# 895     Janice    NaN 1991-11-19 2022-08-13 18:02:00  139791   16.968
#
#      Senior Management                  Team
# 339               True       Human Resources
# 603               True  Business Development
# 895              False  Business Development

# %% [markdown]
# ### Duplicated

# %%
df = pd.read_csv(r'D:\Learning & Projects\Python\Pandas\Boris\employees.csv', parse_dates=['Start Date', 'Last Login Time'])
df['Senior Management'] = df['Senior Management'].astype('bool')
df['Gender'] = df['Gender'].astype('category')
df.sort_values('First Name', inplace = True)
df.head()
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2022-08-13 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2022-08-13 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2022-08-13 14:53:00   52119   11.343
# 937      Aaron    NaN 1986-01-22 2022-08-13 19:39:00   63126   18.424
# 137       Adam   Male 2011-05-21 2022-08-13 01:45:00   95327   15.120
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services
# 937              False  Client Services
# 137              False     Distribution

# %%
df[df['First Name'].duplicated(keep = 'last')].head()
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2022-08-13 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2022-08-13 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2022-08-13 14:53:00   52119   11.343
# 137       Adam   Male 2011-05-21 2022-08-13 01:45:00   95327   15.120
# 141       Adam   Male 1990-12-24 2022-08-13 20:57:00  110194   14.727
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services
# 137              False     Distribution
# 141               True          Product

# %%
df[~df['First Name'].duplicated(keep = False)]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22 2022-08-13 06:29:00   95570   18.523
# 688      Brian    Male 2007-04-07 2022-08-13 22:47:00   93901   17.821
# 190      Carol  Female 1996-03-19 2022-08-13 03:39:00   57783    9.129
# 887      David    Male 2009-12-05 2022-08-13 08:48:00   92242   15.407
# 5       Dennis    Male 1987-04-18 2022-08-13 01:35:00  115163   10.125
# 495     Eugene    Male 1984-05-24 2022-08-13 10:54:00   81077    2.117
# 33        Jean  Female 1993-12-18 2022-08-13 09:07:00  119082   16.180
# 832      Keith    Male 2003-02-12 2022-08-13 15:02:00  120672   19.467
# 291      Tammy  Female 1984-11-11 2022-08-13 10:30:00  132839   17.463
#
#      Senior Management                  Team
# 8                 True           Engineering
# 688               True                 Legal
# 190              False               Finance
# 887              False                 Legal
# ...

# %% [markdown]
# ### .drop_duplicates() Method

# %%
df.drop_duplicates(subset=['First Name', 'Team'], keep=False)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 137       Adam   Male 2011-05-21 2022-08-13 01:45:00   95327   15.120
# 141       Adam   Male 1990-12-24 2022-08-13 20:57:00  110194   14.727
# 300       Alan   Male 1988-06-26 2022-08-13 03:54:00  111786    3.592
# 53        Alan    NaN 2014-03-03 2022-08-13 13:28:00   40341   17.578
# 610       Alan   Male 2012-02-17 2022-08-13 00:26:00   41453   10.084
# ..         ...    ...        ...                 ...     ...      ...
# 448      Wayne   Male 1992-01-30 2022-08-13 15:01:00   81183   17.066
# 943      Wayne   Male 2006-09-08 2022-08-13 11:09:00   67471    2.728
# 637      Wayne   Male 2009-09-02 2022-08-13 01:37:00  126956   18.396
# 941    William   Male 1997-06-26 2022-08-13 08:33:00  104840   15.653
# 450     Willie   Male 2009-08-22 2022-08-13 13:03:00   55038   19.691
#
#      Senior Management             Team
# 137              False     Distribution
# 141               True          Product
# ...

# %% [markdown]
# ### .unique() & .nunique() Method

# %%
df['Team'].unique()
# Out:
# array(['Marketing', 'Client Services', 'Distribution', 'Product',
#        'Human Resources', 'Engineering', 'Finance',
#        'Business Development', 'Sales', nan, 'Legal'], dtype=object)

# %%
len(df['Team'].unique())
# Out:
# 11

# %%
df['Team'].nunique() # Will not consider NAN values
# Out:
# 10

# %%
df['Team'].nunique(dropna = False)
# Out:
# 11
